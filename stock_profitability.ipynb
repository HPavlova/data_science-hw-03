# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
tmp = 'https://textbook.edu.goit.global/python/data-science-xf8b2g-pwa/v1/uk/docs/module-03/hw'
data=pd.read_html(tmp)[0]
data
# Out:
#    Момент наблюдения  Доходность A, %  Доходность B, %  Доходность C, %
# 0                  1               25                0               10
# 1                  2              -10               15               25
# 2                  3               10               -5              -15
# 3                  4                5                5               -5
# 4                  5               35               20               -5
# 5                  6               13               25               15

# %%
data.corr()
# Out:
#                    Момент наблюдения  Доходность A, %  Доходность B, %  \
# Момент наблюдения           1.000000         0.238559         0.677631
# Доходность A, %             0.238559         1.000000         0.075439
# Доходность B, %             0.677631         0.075439         1.000000
# Доходность C, %            -0.196356        -0.408807         0.508034
#
#                    Доходность C, %
# Момент наблюдения        -0.196356
# Доходность A, %          -0.408807
# Доходность B, %           0.508034
# Доходность C, %           1.000000

# %%
plt.figure(figsize=(16,8))
sns.regplot(x=data['Доходность A, %'], y=data['Доходность B, %'], data=data)
plt.show()

# %%
plt.figure(figsize=(16,8))
sns.regplot(x=data['Доходность A, %'], y=data['Доходность C, %'], data=data)
plt.show()

# %%
plt.figure(figsize=(16,8))
sns.regplot(x=data['Доходность B, %'], y=data['Доходность C, %'], data=data)
plt.show()

# %%
plt.figure(figsize=(16,8))
sns.regplot(x=data['Доходность A, %'], y=data['Доходность B, %'], data=data, label='A:B')
sns.regplot(x=data['Доходность A, %'], y=data['Доходность C, %'], data=data, label='A:C')
sns.regplot(x=data['Доходность B, %'], y=data['Доходность C, %'], data=data, label='B:C')
plt.legend()
plt.show()
